# %% [markdown]
# <a href="https://colab.research.google.com/github/SauleRub/DI_Bootcamp/blob/main/Week13/Day5/Week13Day5_MiniProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install selenium
# !pip install beautifulsoup4
# !pip install chromedriver-autoinstaller

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
import chromedriver_autoinstaller
import time

# Auto-install ChromeDriver
chromedriver_autoinstaller.install()

# Set options for headless mode (no browser popup)
options = Options()
options.add_argument('--headless')
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')

# Start the driver
driver = webdriver.Chrome(options=options)

# Go to the scraping-friendly e-commerce demo site
url = "https://books.toscrape.com/"
driver.get(url)

# Wait for page content to load
time.sleep(3)

# Get page HTML source
html = driver.page_source
driver.quit()

# Just to confirm it's loaded correctly:
print(html[:500])  # print first 500 characters
# Out:
# <html lang="en-us" class="no-js"><!--<![endif]--><head>
#         <title>
#     All products | Books to Scrape - Sandbox
# </title>
#
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#         <meta name="created" content="24th Jun 2016 09:29">
#         <meta name="description" content="">
#         <meta name="viewport" content="width=device-width">
#         <meta name="robots" content="NOARCHIVE,NOCACHE">
#
#         <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->

# %%
from bs4 import BeautifulSoup

# Parse the HTML
soup = BeautifulSoup(html, 'html.parser')

# Find all book containers
books = soup.find_all('article', class_='product_pod')

# Extract info for each book
book_data = []
for book in books:
    title = book.h3.a['title']
    price = book.find('p', class_='price_color').text
    availability = book.find('p', class_='instock availability').text.strip()

    book_data.append({
        'title': title,
        'price': price,
        'availability': availability
    })

# Show the first 5 results
book_data[:5]
# Out:
# [{'title': 'A Light in the Attic',
#   'price': '£51.77',
#   'availability': 'In stock'},
#  {'title': 'Tipping the Velvet',
#   'price': '£53.74',
#   'availability': 'In stock'},
#  {'title': 'Soumission', 'price': '£50.10', 'availability': 'In stock'},
#  {'title': 'Sharp Objects', 'price': '£47.82', 'availability': 'In stock'},
#  {'title': 'Sapiens: A Brief History of Humankind',
#   'price': '£54.23',
#   'availability': 'In stock'}]

# %%
import pandas as pd

# Convert to DataFrame
df = pd.DataFrame(book_data)

# Save to CSV
df.to_csv('books.csv', index=False)

print("📁 Data saved to 'books.csv'")
df.head()
# Out:
# 📁 Data saved to 'books.csv'
#                                    title   price availability
# 0                   A Light in the Attic  £51.77     In stock
# 1                     Tipping the Velvet  £53.74     In stock
# 2                             Soumission  £50.10     In stock
# 3                          Sharp Objects  £47.82     In stock
# 4  Sapiens: A Brief History of Humankind  £54.23     In stock

# %%
from google.colab import files
files.download('books.csv')
